# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
plt.style.use('seaborn')
data_path='/kaggle/input/bike-sharing-demand/'
df_train=pd.read_csv(data_path +'train.csv', parse_dates=['datetime'])
df_test=pd.read_csv(data_path +'test.csv', parse_dates=['datetime'])
submission=pd.read_csv(data_path +'sampleSubmission.csv')
# Out:
# /tmp/ipykernel_32/2620956226.py:7: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
def RMSLE(y_real, y_pred):
    L1 = np.log1p(np.exp(y_real))
    L2 = np.log1p(np.exp(y_pred))    
    calc = (L1 - L2) ** 2
    return np.sqrt(np.mean(calc))

# %%
# RMSLE score 
from sklearn.metrics import make_scorer
rmsle_score=make_scorer(RMSLE)

# %%
df_train.tail()
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 10881 2012-12-19 19:00:00       4        0           1        1  15.58
# 10882 2012-12-19 20:00:00       4        0           1        1  14.76
# 10883 2012-12-19 21:00:00       4        0           1        1  13.94
# 10884 2012-12-19 22:00:00       4        0           1        1  13.94
# 10885 2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# 10881  19.695        50    26.0027       7         329    336
# 10882  17.425        57    15.0013      10         231    241
# 10883  15.910        61    15.0013       4         164    168
# 10884  17.425        61     6.0032      12         117    129
# 10885  16.665        66     8.9981       4          84     88

# %% [markdown]
# # データの前処理

# %% [markdown]
# ### 年月日に分割

# %%
def split_datetime(df):
    df['year'] = df['datetime'].dt.year
    df['month'] = df['datetime'].dt.month
    df['day'] = df['datetime'].dt.day
    df['hour'] = df['datetime'].dt.hour
    df['weekday'] = df['datetime'].dt.weekday
    df = df.drop(['datetime'],axis = 1)
    return df

# %%
data=pd.concat([df_train, df_test], ignore_index=True)
data.tail()
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 17374 2012-12-31 19:00:00       1        0           1        2  10.66
# 17375 2012-12-31 20:00:00       1        0           1        2  10.66
# 17376 2012-12-31 21:00:00       1        0           1        1  10.66
# 17377 2012-12-31 22:00:00       1        0           1        1  10.66
# 17378 2012-12-31 23:00:00       1        0           1        1  10.66
#
#         atemp  humidity  windspeed  casual  registered  count
# 17374  12.880        60    11.0014     NaN         NaN    NaN
# 17375  12.880        60    11.0014     NaN         NaN    NaN
# 17376  12.880        60    11.0014     NaN         NaN    NaN
# 17377  13.635        56     8.9981     NaN         NaN    NaN
# 17378  13.635        65     8.9981     NaN         NaN    NaN

# %% [markdown]
# ## 特徴量エンジニアリング

# %% [markdown]
# #### 共通　（data_1）
# * weather = 4 → 3 （4は1つのみ）
# * windspeed = 0 → 線型補間
# * datetime → delete　（被っているため）
# * count　→ log convert　（対数変換）
#
# #### data_2
# * atempt → delete （tempを使う）

# %%
data_1 = data.copy()
data_1.replace({'weather': 4}, 3, inplace=True)
data_1.loc[:, 'datetime'] = pd.to_datetime(data_1.loc[:, 'datetime'])
data_1.set_index('datetime', inplace=True)
data_1.replace({'windspeed': 0}, np.nan, inplace=True)
data_1['windspeed'] = data_1['windspeed'].interpolate(method='time', limit_direction='both')

data_1.tail()
# Out:
# /tmp/ipykernel_32/2754258063.py:3: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   data_1.loc[:, 'datetime'] = pd.to_datetime(data_1.loc[:, 'datetime'])
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2012-12-31 19:00:00       1        0           1        2  10.66  12.880
# 2012-12-31 20:00:00       1        0           1        2  10.66  12.880
# 2012-12-31 21:00:00       1        0           1        1  10.66  12.880
# 2012-12-31 22:00:00       1        0           1        1  10.66  13.635
# 2012-12-31 23:00:00       1        0           1        1  10.66  13.635
#
#                      humidity  windspeed  casual  registered  count
# datetime
# 2012-12-31 19:00:00        60    11.0014     NaN         NaN    NaN
# 2012-12-31 20:00:00        60    11.0014     NaN         NaN    NaN
# 2012-12-31 21:00:00        60    11.0014     NaN         NaN    NaN
# 2012-12-31 22:00:00        56     8.9981     NaN         NaN    NaN
# 2012-12-31 23:00:00        65     8.9981     NaN         NaN    NaN

# %%
data_1 = data_1.reset_index()
data_1 = split_datetime(data_1)
data_1.tail()
# Out:
#        season  holiday  workingday  weather   temp   atemp  humidity  \
# 17374       1        0           1        2  10.66  12.880        60
# 17375       1        0           1        2  10.66  12.880        60
# 17376       1        0           1        1  10.66  12.880        60
# 17377       1        0           1        1  10.66  13.635        56
# 17378       1        0           1        1  10.66  13.635        65
#
#        windspeed  casual  registered  count  year  month  day  hour  weekday
# 17374    11.0014     NaN         NaN    NaN  2012     12   31    19        0
# 17375    11.0014     NaN         NaN    NaN  2012     12   31    20        0
# 17376    11.0014     NaN         NaN    NaN  2012     12   31    21        0
# 17377     8.9981     NaN         NaN    NaN  2012     12   31    22        0
# 17378     8.9981     NaN         NaN    NaN  2012     12   31    23        0

# %%
data_2 = data_1.drop('atemp', axis=1) 
data_2.tail()
# Out:
#        season  holiday  workingday  weather   temp  humidity  windspeed  \
# 17374       1        0           1        2  10.66        60    11.0014
# 17375       1        0           1        2  10.66        60    11.0014
# 17376       1        0           1        1  10.66        60    11.0014
# 17377       1        0           1        1  10.66        56     8.9981
# 17378       1        0           1        1  10.66        65     8.9981
#
#        casual  registered  count  year  month  day  hour  weekday
# 17374     NaN         NaN    NaN  2012     12   31    19        0
# 17375     NaN         NaN    NaN  2012     12   31    20        0
# 17376     NaN         NaN    NaN  2012     12   31    21        0
# 17377     NaN         NaN    NaN  2012     12   31    22        0
# 17378     NaN         NaN    NaN  2012     12   31    23        0

# %% [markdown]
# ## 仮説7
# * day → delete　（trainとtestで異なるため）

# %%
data_7_1 = data_2.drop('day', axis=1)

# %%
data_7_2 = data_2.drop('day', axis=1)

# %%
X_train_val_7_1=data_7_1[~pd.isnull(data_7_1['count'])]
X_test_7_1=data_7_1[pd.isnull(data_7_1['count'])]
X_train_val_7_1 = X_train_val_7_1.drop(['registered', 'casual', 'count'], axis=1)
X_test_7_1 = X_test_7_1.drop(['registered', 'casual', 'count'], axis=1)
y_train_val_7_1=np.log(df_train['count']) #　countはlogに

# %%
X_train_7_1, X_val_7_1, y_train_7_1, y_val_7_1 = train_test_split(
    X_train_val_7_1, y_train_val_7_1, test_size = 0.3, random_state = 1)

# %%
X_train_7_1.shape, X_val_7_1.shape, X_test_7_1.shape
# Out:
# ((7620, 11), (3266, 11), (6493, 11))

# %% [markdown]
# ## 検証

# %% [markdown]
# ## LightGBM + Oputuna

# %%
from lightgbm import LGBMRegressor
import optuna
from optuna.samplers import TPESampler

def objective_func(trial):
    # 探索空間
    params = {
        'num_leaves': trial.suggest_int('num_leaves',2, 30),
        'max_depth': trial.suggest_int('max_depth',2, 30),
        'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
        'n_estimators': trial.suggest_int('n_estimators', 100, 800),
#         'min_child_samples': trial.suggest_int('min_child_samples', 2, 30),
#         'subsample': trial.suggest_discrete_uniform('subsample', 0.5, 1, 0.1)
        # low, high, step
    }
    model=LGBMRegressor(**params)#　辞書型の受け渡し
    lgbm_model = model.fit(X_train_7_1, y_train_7_1, eval_set=[(X_val_7_1, y_val_7_1)], verbose=False, early_stopping_rounds=25)
    score = RMSLE(y_val_7_1, lgbm_model.predict(X_val_7_1))
    return score

# %%
sampler = TPESampler(seed=10)
study = optuna.create_study(direction='minimize', sampler=sampler)
study.optimize(objective_func, n_trials=50)
trial = study.best_trial
trial_params = trial.params
print('Best Trial: score {},\n params {}'.format(trial.value, trial_params))
# Out:
# [I 2023-06-13 08:33:38,354] A new study created in memory with name: no-name-fb7a3d65-ac68-493a-8920-8957e42780fe
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:33:39,853] Trial 0 finished with value: 0.9180742847299579 and parameters: {'num_leaves': 24, 'max_depth': 2, 'learning_rate': 0.0014731303415988814, 'n_estimators': 624}. Best is trial 0 with value: 0.9180742847299579.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:33:42,145] Trial 1 finished with value: 1.4145524276245045 and parameters: {'num_leaves': 16, 'max_depth': 8, 'learning_rate': 9.779447595326336e-06, 'n_estimators': 633}. Best is trial 0 with value: 0.9180742847299579.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:33:43,485] Trial 2 finished with value: 0.6549377537572053 and parameters: {'num_leaves': 6, 'max_depth': 4, 'learning_rate': 0.0026717701401254407, 'n_estimators': 768}. Best is trial 2 with value: 0.6549377537572053.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:33:43,955] Trial 3 finished with value: 0.7377779744743346 and parameters: {'num_leaves': 2, 'max_depth': 16, 'learning_rate': 0.011563912803570744, 'n_estimators': 529}. Best is trial 2 with value: 0.6549377537572053.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:33:46,441] Trial 4 finished with value: 0.2766485622412146 and parameters: {'num_leaves': 22, 'max_depth': 10, 'learning_rate': 0.03880347432921835, 'n_estimators': 600}. Best is trial 4 with value: 0.2766485622412146.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:33:48,455] Trial 5 finished with value: 1.3737586495805205 and parameters: {'num_leaves': 17, 'max_depth': 6, 'learning_rate': 7.357051569541081e-05, 'n_estimators': 572}. Best is trial 4 with value: 0.2766485622412146.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:33:49,911] Trial 6 finished with value: 0.9549626479504275 and parameters: {'num_leaves': 14, 'max_depth': 14, 'learning_rate': 0.001226972678850034, 'n_estimators': 459}. Best is trial 4 with value: 0.2766485622412146.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:33:51,924] Trial 7 finished with value: 0.33523758051968494 and parameters: {'num_leaves': 20, 'max_depth': 19, 'learning_rate': 0.01061979135095781, 'n_estimators': 465}. Best is trial 4 with value: 0.2766485622412146.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:33:53,622] Trial 8 finished with value: 1.420629528350555 and parameters: {'num_leaves': 28, 'max_depth': 11, 'learning_rate': 2.8333273009960214e-06, 'n_estimators': 310}. Best is trial 4 with value: 0.2766485622412146.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:33:54,458] Trial 9 finished with value: 1.4208003914995744 and parameters: {'num_leaves': 5, 'max_depth': 26, 'learning_rate': 1.7158589997464473e-06, 'n_estimators': 539}. Best is trial 4 with value: 0.2766485622412146.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:33:55,282] Trial 10 finished with value: 0.28153426577036195 and parameters: {'num_leaves': 28, 'max_depth': 22, 'learning_rate': 0.08583299199738095, 'n_estimators': 152}. Best is trial 4 with value: 0.2766485622412146.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:33:56,057] Trial 11 finished with value: 0.28202963837665485 and parameters: {'num_leaves': 29, 'max_depth': 24, 'learning_rate': 0.09823103047404134, 'n_estimators': 136}. Best is trial 4 with value: 0.2766485622412146.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:33:57,507] Trial 12 finished with value: 0.28263847324008695 and parameters: {'num_leaves': 25, 'max_depth': 30, 'learning_rate': 0.0556057632789106, 'n_estimators': 264}. Best is trial 4 with value: 0.2766485622412146.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:33:58,012] Trial 13 finished with value: 0.2885962228468409 and parameters: {'num_leaves': 22, 'max_depth': 20, 'learning_rate': 0.09867648634158262, 'n_estimators': 104}. Best is trial 4 with value: 0.2766485622412146.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:02,312] Trial 14 finished with value: 0.28613968919641664 and parameters: {'num_leaves': 30, 'max_depth': 12, 'learning_rate': 0.012530974608989573, 'n_estimators': 759}. Best is trial 4 with value: 0.2766485622412146.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:03,312] Trial 15 finished with value: 1.3188772875962764 and parameters: {'num_leaves': 12, 'max_depth': 20, 'learning_rate': 0.0003113260042053129, 'n_estimators': 318}. Best is trial 4 with value: 0.2766485622412146.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:04,532] Trial 16 finished with value: 0.31096924319091845 and parameters: {'num_leaves': 26, 'max_depth': 9, 'learning_rate': 0.023791245575184312, 'n_estimators': 228}. Best is trial 4 with value: 0.2766485622412146.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:06,302] Trial 17 finished with value: 0.28809722441011526 and parameters: {'num_leaves': 20, 'max_depth': 24, 'learning_rate': 0.02941670960579257, 'n_estimators': 385}. Best is trial 4 with value: 0.2766485622412146.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:09,389] Trial 18 finished with value: 0.3642959955382789 and parameters: {'num_leaves': 21, 'max_depth': 17, 'learning_rate': 0.005114648801076977, 'n_estimators': 704}. Best is trial 4 with value: 0.2766485622412146.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:10,264] Trial 19 finished with value: 0.35914431972206184 and parameters: {'num_leaves': 11, 'max_depth': 30, 'learning_rate': 0.032726543678302036, 'n_estimators': 182}. Best is trial 4 with value: 0.2766485622412146.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:13,148] Trial 20 finished with value: 0.3783394327238085 and parameters: {'num_leaves': 26, 'max_depth': 23, 'learning_rate': 0.007346277057677537, 'n_estimators': 400}. Best is trial 4 with value: 0.2766485622412146.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:14,096] Trial 21 finished with value: 0.28086535592901424 and parameters: {'num_leaves': 30, 'max_depth': 26, 'learning_rate': 0.09461396411720023, 'n_estimators': 155}. Best is trial 4 with value: 0.2766485622412146.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:15,288] Trial 22 finished with value: 0.28831561724900856 and parameters: {'num_leaves': 30, 'max_depth': 27, 'learning_rate': 0.04191195474071417, 'n_estimators': 203}. Best is trial 4 with value: 0.2766485622412146.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:16,229] Trial 23 finished with value: 0.2870312221960215 and parameters: {'num_leaves': 27, 'max_depth': 27, 'learning_rate': 0.0628131114222376, 'n_estimators': 150}. Best is trial 4 with value: 0.2766485622412146.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:17,612] Trial 24 finished with value: 0.31026143459501937 and parameters: {'num_leaves': 23, 'max_depth': 22, 'learning_rate': 0.020637143456280784, 'n_estimators': 290}. Best is trial 4 with value: 0.2766485622412146.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:18,926] Trial 25 finished with value: 0.2759095881632714 and parameters: {'num_leaves': 18, 'max_depth': 14, 'learning_rate': 0.08468794535980895, 'n_estimators': 374}. Best is trial 25 with value: 0.2759095881632714.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:20,453] Trial 26 finished with value: 0.29684897860015247 and parameters: {'num_leaves': 18, 'max_depth': 12, 'learning_rate': 0.02238801524401481, 'n_estimators': 402}. Best is trial 25 with value: 0.2759095881632714.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:22,762] Trial 27 finished with value: 0.4382326317656688 and parameters: {'num_leaves': 14, 'max_depth': 15, 'learning_rate': 0.0043859759201113555, 'n_estimators': 672}. Best is trial 25 with value: 0.2759095881632714.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:24,600] Trial 28 finished with value: 0.27971239689023697 and parameters: {'num_leaves': 19, 'max_depth': 9, 'learning_rate': 0.043234516492846084, 'n_estimators': 499}. Best is trial 25 with value: 0.2759095881632714.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:25,301] Trial 29 finished with value: 0.9374299098068879 and parameters: {'num_leaves': 19, 'max_depth': 2, 'learning_rate': 0.0016633219421579833, 'n_estimators': 514}. Best is trial 25 with value: 0.2759095881632714.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:28,410] Trial 30 finished with value: 0.2935609677420782 and parameters: {'num_leaves': 23, 'max_depth': 9, 'learning_rate': 0.014710963118589106, 'n_estimators': 598}. Best is trial 25 with value: 0.2759095881632714.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:29,450] Trial 31 finished with value: 0.28613928232781766 and parameters: {'num_leaves': 14, 'max_depth': 7, 'learning_rate': 0.05458558077672857, 'n_estimators': 354}. Best is trial 25 with value: 0.2759095881632714.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:31,037] Trial 32 finished with value: 0.2815579654126757 and parameters: {'num_leaves': 16, 'max_depth': 13, 'learning_rate': 0.03923098809176476, 'n_estimators': 485}. Best is trial 25 with value: 0.2759095881632714.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:32,675] Trial 33 finished with value: 0.2812615216423695 and parameters: {'num_leaves': 10, 'max_depth': 10, 'learning_rate': 0.040399745861441294, 'n_estimators': 644}. Best is trial 25 with value: 0.2759095881632714.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:34,591] Trial 34 finished with value: 0.36976369456915137 and parameters: {'num_leaves': 24, 'max_depth': 6, 'learning_rate': 0.007975093414346802, 'n_estimators': 422}. Best is trial 25 with value: 0.2759095881632714.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:37,157] Trial 35 finished with value: 0.2926221927530185 and parameters: {'num_leaves': 18, 'max_depth': 17, 'learning_rate': 0.017044022313299996, 'n_estimators': 597}. Best is trial 25 with value: 0.2759095881632714.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:38,560] Trial 36 finished with value: 0.27622208282024036 and parameters: {'num_leaves': 16, 'max_depth': 5, 'learning_rate': 0.0929855376283991, 'n_estimators': 564}. Best is trial 25 with value: 0.2759095881632714.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:40,412] Trial 37 finished with value: 0.5419910363531052 and parameters: {'num_leaves': 16, 'max_depth': 5, 'learning_rate': 0.0033036681996841595, 'n_estimators': 564}. Best is trial 25 with value: 0.2759095881632714.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:41,458] Trial 38 finished with value: 0.5389577917549064 and parameters: {'num_leaves': 21, 'max_depth': 3, 'learning_rate': 0.006826181523611713, 'n_estimators': 495}. Best is trial 25 with value: 0.2759095881632714.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:43,809] Trial 39 finished with value: 0.3493117406821749 and parameters: {'num_leaves': 15, 'max_depth': 8, 'learning_rate': 0.011818052323876062, 'n_estimators': 443}. Best is trial 25 with value: 0.2759095881632714.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:45,184] Trial 40 finished with value: 0.2828441391597191 and parameters: {'num_leaves': 8, 'max_depth': 5, 'learning_rate': 0.04563704291559983, 'n_estimators': 705}. Best is trial 25 with value: 0.2759095881632714.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:46,426] Trial 41 finished with value: 0.27692020196951744 and parameters: {'num_leaves': 18, 'max_depth': 11, 'learning_rate': 0.0958449677797195, 'n_estimators': 551}. Best is trial 25 with value: 0.2759095881632714.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:48,491] Trial 42 finished with value: 0.2836665823590003 and parameters: {'num_leaves': 18, 'max_depth': 11, 'learning_rate': 0.02777760306677362, 'n_estimators': 549}. Best is trial 25 with value: 0.2759095881632714.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:49,937] Trial 43 finished with value: 0.2775847649977413 and parameters: {'num_leaves': 20, 'max_depth': 15, 'learning_rate': 0.07191562417354118, 'n_estimators': 598}. Best is trial 25 with value: 0.2759095881632714.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:51,801] Trial 44 finished with value: 0.27385741129485314 and parameters: {'num_leaves': 17, 'max_depth': 14, 'learning_rate': 0.06977953935011831, 'n_estimators': 633}. Best is trial 44 with value: 0.27385741129485314.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:53,530] Trial 45 finished with value: 0.27417416239178105 and parameters: {'num_leaves': 13, 'max_depth': 14, 'learning_rate': 0.07109584814668528, 'n_estimators': 646}. Best is trial 44 with value: 0.27385741129485314.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:55,954] Trial 46 finished with value: 0.2890002551623001 and parameters: {'num_leaves': 14, 'max_depth': 14, 'learning_rate': 0.019518240061547877, 'n_estimators': 800}. Best is trial 44 with value: 0.27385741129485314.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:57,380] Trial 47 finished with value: 0.2768688840701284 and parameters: {'num_leaves': 12, 'max_depth': 17, 'learning_rate': 0.06231525909439107, 'n_estimators': 650}. Best is trial 44 with value: 0.27385741129485314.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:34:59,008] Trial 48 finished with value: 0.3296290909555549 and parameters: {'num_leaves': 9, 'max_depth': 13, 'learning_rate': 0.014861692344643114, 'n_estimators': 691}. Best is trial 44 with value: 0.27385741129485314.
# /tmp/ipykernel_32/4113507711.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform("learning_rate", 1e-6, 1e-1),
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.10/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [I 2023-06-13 08:35:00,538] Trial 49 finished with value: 0.27611290198135285 and parameters: {'num_leaves': 12, 'max_depth': 18, 'learning_rate': 0.06415406984756214, 'n_estimators': 749}. Best is trial 44 with value: 0.27385741129485314.
# Best Trial: score 0.27385741129485314,
#  params {'num_leaves': 17, 'max_depth': 14, 'learning_rate': 0.06977953935011831, 'n_estimators': 633}

# %%
from optuna import visualization
optuna.visualization.plot_param_importances(study)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="1dc763b2-02f3-49b9-ad14-375a33fdb118" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1dc763b2-02f3-49b9-ad14-375a33fdb118")) {                    Plotly.newPlot(                        "1dc763b2-02f3-49b9-ad14-375a33fdb118",                        [{"cliponaxis":false,"hovertemplate":["n_estimators (IntDistribution): 0.010096707400010025<extra></extra>","max_depth (IntDistribution): 0.0412277683462801<extra></extra>","num_leaves (IntDistribution): 0.18068557330743626<extra></extra>","learning_rate (FloatDistribution): 0.7679899509462736<extra></extra>"],"marker":{"color":"rgb(66,146,198)"},"orientation":"h","text":["0.01","0.04","0.18","0.77"],"textposition":"outside","x":[0.010096707400010025,0.0412277683462801,0.18068557330743626,0.7679899509462736],"y":["n_estimators","max_depth","num_leaves","learning_rate"],"type":"bar"}],                        {"showlegend":false,"title":{"text":"Hyperparameter Importances"},"xaxis":{"title":{"text":"Importance for Objective Value"}},"yaxis":{"title":{"text":"Hyperparameter"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{ ...

# %%
from sklearn.model_selection import cross_val_score
lgbm_best=LGBMRegressor(**trial_params)
score=cross_val_score(lgbm_best, X_train_7_1, y_train_7_1, cv=5, scoring=rmsle_score, verbose=True)
print(score)
print(np.mean(score))
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [0.29777458 0.27650067 0.28748471 0.28646362 0.29619211]
# 0.28888313515004665
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   11.2s finished

# %%
lgbm_best.fit(X_train_7_1, y_train_7_1)
# Out:
# LGBMRegressor(learning_rate=0.06977953935011831, max_depth=14, n_estimators=633,
#               num_leaves=17)

# %%
y_ret_7_1=lgbm_best.predict(X_test_7_1)

# %%
submission_7_1 = submission.copy()
submission_7_1['count']=np.exp(y_ret_7_1)
submission_7_1.to_csv('/kaggle/working/submission_7_1.csv', index=False)

# %% [markdown]
# <a href="submission_7_1.csv"> Download File </a>

# %%
ls
# Out:
# ls: cannot access 'kaggle': No such file or directory

# %%
pd.read_csv('submission_7_1.csv')
# Out:
#                  datetime       count
# 0     2011-01-20 00:00:00   10.482539
# 1     2011-01-20 01:00:00    3.300955
# 2     2011-01-20 02:00:00    2.239297
# 3     2011-01-20 03:00:00    1.935562
# 4     2011-01-20 04:00:00    1.782357
# ...                   ...         ...
# 6488  2012-12-31 19:00:00  273.206763
# 6489  2012-12-31 20:00:00  180.455421
# 6490  2012-12-31 21:00:00  133.874408
# 6491  2012-12-31 22:00:00  100.306951
# 6492  2012-12-31 23:00:00   52.547622
#
# [6493 rows x 2 columns]

# %%
submission = pd.read_csv('../input/bike-sharing-demand/sampleSubmission.csv')
submission['count']=np.exp(y_ret)
submission.to_csv('submission.csv', index=False)
